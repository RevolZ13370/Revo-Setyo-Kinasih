# %% [markdown]
# <a href="https://colab.research.google.com/github/RevolZ13370/Revo-Setyo-Kinasih-ALPRO/blob/Jobsheet-01/Revo_Setyo_Kinasih_Jobsheet_08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Praktikum

# %% [markdown]
# Praktikum 01 – Fungsi Dasar dengan def

# %%
def sapa():
  print("Halo, selamat datang di Politeknik Negeri Semarang!")

sapa()
# Out:
# Halo, selamat datang di Politeknik Negeri Semarang!

# %% [markdown]
# Praktikum 02 – Fungsi dengan Parameter dan Return

# %%
def tambah(a, b):
  return a + b

hasil = tambah(7, 3)
print("Hasil penjumlahan:", hasil)
# Out:
# Hasil penjumlahan: 10

# %% [markdown]
# Praktikum 03 – Fungsi dengan Default Argument

# %%
def sapa(nama="Mahasiswa"):
  print(f"Halo, {nama}!")

sapa() # tanpa argumen
sapa("Andi") # dengan argumen
# Out:
# Halo, Mahasiswa!
# Halo, Andi!

# %% [markdown]
# Praktikum 04 – Fungsi dengan *args dan **kwargs

# %%
def jumlahkan(*args):
  return sum(args)

def biodata(**kwargs):
  for key, value in kwargs.items():
    print(f"{key}: {value}")

print("Total:", jumlahkan(1, 2, 3, 4, 5))
biodata(Nama="Budi", Umur=20, Prodi="TRK")
# Out:
# Total: 15
# Nama: Budi
# Umur: 20
# Prodi: TRK

# %% [markdown]
# Praktikum 05 – Scope Variabel

# %%
x = 10

def ubah():
  x = 5
  print("Nilai lokal:", x)

ubah()
print("Nilai global:", x)
# Out:
# Nilai lokal: 5
# Nilai global: 10

# %% [markdown]
# Praktikum 06 – Fungsi Lambda

# %%
kali = lambda x, y: x * y

print("Hasil perkalian:", kali(4, 5))
# Out:
# Hasil perkalian: 20
# Hasil perkalian: 25

# %% [markdown]
# Praktikum 07 – Fungsi Decorator

# %%
def decorator_sapa(fungsi):
  def wrapper():
    print("Sebelum fungsi dijalankan...")
    fungsi()
    print("Setelah fungsi dijalankan...")
  return wrapper

@decorator_sapa
def sapa():
  print("Halo, Mahasiswa Polines!")


sapa()
# Out:
# Sebelum fungsi dijalankan...
# Halo, Mahasiswa Polines!
# Setelah fungsi dijalankan...

# %% [markdown]
# Praktikum 08 – Studi Kasus: Menghitung Rata-rata Nilai Mahasiswa

# %%
def hitung_rata(data):
  return sum(data) / len(data)

nilai = [80, 90, 85]
rata = hitung_rata(nilai)

print("Rata-rata nilai:", rata)
# Out:
# Rata-rata nilai: 85.0

# %% [markdown]
# # Penugasan

# %% [markdown]
# Penugasan 01 - Fungsi Sederhana

# %%
def perkenalan(nama, prodi):
  print(f"Halo, nama saya {nama}, saya dari {prodi}.")

perkenalan("Andi", "Teknologi Rekayasa Komputer")
perkenalan("Budi", "Teknik Informatika")
perkenalan("Mukhlis", "Teknik Telekomunikasi")
# Out:
# Halo, nama saya Andi, saya dari Teknologi Rekayasa Komputer.
# Halo, nama saya Budi, saya dari Teknik Informatika.
# Halo, nama saya Mukhlis, saya dari Teknik Telekomunikasi.

# %% [markdown]
# Penugasan 02 - Fungsi dengan Parameter dan Return

# %%
def luas_persegi(panjang, lebar):
  return panjang * lebar

luas1 = luas_persegi(5, 10)
print("Luas persegi 1:", luas1)

luas2 = luas_persegi(6, 12)
print("Luas persegi 2:", luas2)

luas3 = luas_persegi(7, 4)
print("Luas persegi 3:", luas3)
# Out:
# Luas persegi 1: 50
# Luas persegi 2: 72
# Luas persegi 3: 28

# %% [markdown]
# Penugasan 03 - Fungsi dengan Default Argument

# %%
def salam(waktu="pagi", nama="Mahasiswa"):
  print(f"Selamat {waktu}, {nama}!")

salam()
salam("sore", "Revo")
salam("malam", "Mukhlis")
salam("pagi", "Bimo")
# Out:
# Selamat pagi, Mahasiswa!
# Selamat sore, Revo!
# Selamat malam, Mukhlis!
# Selamat pagi, Bimo!

# %% [markdown]
# Penugasan 04 - *Fungsi dengan args

# %%
def jumlahkan_semua(*angka):
  return sum(angka)

soal1 = [1, 2, 4]
soal2 = [5, 6, 2, 8, 1]
soal3 = [2, 6, 3, 5, 8, 6, 5]

print("Penjumlahan 3 biangan : ", jumlahkan_semua(*soal1))
print("Penjumlahan 5 biangan : ", jumlahkan_semua(*soal2))
print("Penjumlahan 7 biangan : ", jumlahkan_semua(*soal3))
# Out:
# Penjumlahan 3 biangan :  7
# Penjumlahan 5 biangan :  22
# Penjumlahan 7 biangan :  35

# %% [markdown]
# Penugasan 05 - **Fungsi dengan kwargs

# %%
def info_barang(**data):
  for key, value in data.items():
        print(f"{key} : {value}")

info_barang(Nama="Buku", Harga=15000, Stok=30)
# Out:
# Nama : Buku
# Harga : 15000
# Stok : 30

# %% [markdown]
# Penugasan 06 - Scope Variabel

# %%
x = 100
def ubah():
    x = 50
    print("Nilai Lokal:", x)

ubah()
print("Nilai Global:", x)
# Out:
# Nilai Lokal: 50
# Nilai Global: 100

# %% [markdown]
# Penugasan 07 - Fungsi Lambda

# %%
import math

kuadrat = lambda x: x ** 2
k_lingkaran = lambda r: 2 * math.pi * r

angka = 5
jari_jari = 7
hasil_kuadrat = kuadrat(angka)
hasil_keliling= k_lingkaran(jari_jari)

print(f"Kuadrat dari {angka} adalah {hasil_kuadrat}")
print(f"Hasil Keliling Lingkaran dengan jari2 {jari_jari} adalah {hasil_keliling:.2f}:")
# Out:
# Kuadrat dari 5 adalah 25
# Hasil Keliling Lingkaran dengan jari2 7 adalah 43.98:

# %% [markdown]
# Penugasan 08 - Fungsi Decorator

# %%
def decorator_halo(fungsi):
    def wrapper():
        print("Memulai Fungsi...")
        fungsi()
        print("Fungsi selesai dijalankan...")
    return wrapper

@decorator_halo
def halo():
    print("Halo, Mahasiswa Polines!")
halo()

# %% [markdown]
# Penugasan 09 - Studi Kasus Nyata Program Nilai

# %%
def input_nilai():

    daftar_nilai = []
    print("--- Input Nilai Mahasiswa ---")
    print("Masukkan nilai satu per satu. Ketik 'selesai' jika sudah.")
    while True:
        masukan = input("Masukkan nilai: ")
        if masukan.lower() == 'selesai':
            break
        try:
            nilai = float(masukan)
            daftar_nilai.append(nilai)
        except ValueError:
            print("Input tidak valid. Silakan masukkan angka.")
    return daftar_nilai


def hitung_rata(daftar_nilai):
    """
    Menghitung rata-rata dari sebuah list nilai.
    Mengembalikan 0 jika list kosong untuk menghindari pembagian dengan nol.
    """
    if not daftar_nilai:
        return 0
    total = sum(daftar_nilai)
    rata_rata = total / len(daftar_nilai)
    return rata_rata

def status_kelulusan(rata):
    if rata >= 60:
        return "Lulus"
    else:
        return "Tidak Lulus"

if __name__ == "__main__":
    nilai_mahasiswa = input_nilai()

    if not nilai_mahasiswa:
        print("\nTidak ada nilai yang dimasukkan. Program berhenti.")
    else:
        nilai_rata_rata = hitung_rata(nilai_mahasiswa)
        print(f"\nDaftar Nilai: {nilai_mahasiswa}")
        print(f"Rata-rata Nilai: {nilai_rata_rata:.2f}")

        status = status_kelulusan(nilai_rata_rata)
        print(f"Status Kelulusan: {status}")

        print("\n--- Menghitung Nilai Akhir dengan Bobot ---")
        try:
            input_tugas = float(input("Masukkan nilai Tugas (0-100): "))
            input_ujian = float(input("Masukkan nilai Ujian (0-100): "))

            nilai_akhir = hitung_nilai_akhir(input_tugas, input_ujian)
            print(f"Nilai Akhir (40% Tugas + 60% Ujian): {nilai_akhir:.2f}")

        except ValueError:
            print("Input untuk nilai tugas atau ujian tidak valid.")

hitung_nilai_akhir = lambda nilai_tugas, nilai_ujian: (0.4 * nilai_tugas) + (0.6 * nilai_ujian)
# Out:
# --- Input Nilai Mahasiswa ---
# Masukkan nilai satu per satu. Ketik 'selesai' jika sudah.
# Masukkan nilai: selesai
#
# Tidak ada nilai yang dimasukkan. Program berhenti.
