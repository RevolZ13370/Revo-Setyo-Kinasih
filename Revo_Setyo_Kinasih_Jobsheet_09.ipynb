# %% [markdown]
# <a href="https://colab.research.google.com/github/RevolZ13370/Revo-Setyo-Kinasih-ALPRO/blob/Jobsheet-01/Revo_Setyo_Kinasih_Jobsheet_09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Praktikum

# %% [markdown]
# Praktikum 01 - Menggunakan Modul math

# %%
import math

angka = 16
hasil1 = math.sqrt(angka)
hasil2 = math.pow(2, 5)
print("Akar kuadrat dari", angka, "=", hasil1)
print("2 pangkat 5 =", hasil2)
# Out:
# Akar kuadrat dari 16 = 4.0
# 2 pangkat 5 = 32.0

# %% [markdown]
# Praktikum 02 – Menggunakan from ... import ...

# %%
from math import sqrt

angka = 25
hasil = sqrt(angka)
print("Akar kuadrat dari", angka, "=", hasil)
# Out:
# Akar kuadrat dari 25 = 5.0

# %% [markdown]
# Praktikum 03 – Memberi Alias Modul

# %%
import numpy as np

data = np.array([1, 2, 3])
print("Isi array =", data)
# Out:
# Isi array = [1 2 3]

# %% [markdown]
# Praktikum 04 – Eksplorasi math, random, dan sys

# %%
import math
import random
import sys

hasil1 = math.sqrt(81)
hasil2 = random.randint(1, 10)
versi = sys.version

print("Akar kuadrat 81 =", hasil1)
print("Angka acak 1–10 =", hasil2)
print("Versi Python =", versi)
# Out:
# Akar kuadrat 81 = 9.0
# Angka acak 1–10 = 7
# Versi Python = 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]

# %% [markdown]
# Praktikum 05 – Membuat Modul Sendiri

# %%
# %%writefile modulku.py
def halo(nama):
  print(f"Halo, {nama}! Selamat belajar Python di Polines.")
# Out:
# Writing modulku.py

# %%
import modulku

modulku.halo("Mahasiswa Polines")
# Out:
# Halo, Mahasiswa Polines! Selamat belajar Python di Polines.

# %% [markdown]
# Praktikum 06 – Instalasi Modul dengan pip

# %%
import requests

response = requests.get("https://www.polines.ac.id")
print("Status code:", response.status_code)
# Out:
# Status code: 403

# %% [markdown]
# # Penugasan

# %% [markdown]
# Penugasan 01 - Eksperimen dengan Modul math

# %%
import math

def luas_lingkaran(r):
    return math.pi * r ** 2

jari_jari1 = 7
jari_jari2 = 10

print("Luas lingkaran dengan jari-jari 7 =", luas_lingkaran(jari_jari1))
print("Luas lingkaran dengan jari-jari 10 =", luas_lingkaran(jari_jari2))
# Out:
# Luas lingkaran dengan jari-jari 7 = 153.93804002589985
# Luas lingkaran dengan jari-jari 10 = 314.1592653589793

# %% [markdown]
# Penugasan 02 - Eksperimen dengan Modul random

# %%
import random

for i in range(5):
    angka_acak = random.randint(1, 100)
    print("Angka acak ke-{}: {}".format(i+1, angka_acak))
# Out:
# Angka acak ke-1: 37
# Angka acak ke-2: 31
# Angka acak ke-3: 75
# Angka acak ke-4: 31
# Angka acak ke-5: 46

# %% [markdown]
# Penugasan 03 - Modul sys

# %%
import sys

ver1 = sys.platform
ver2 = sys.version

print("Platform yang digunakan adalah", ver1)
print("Versi phyton",ver2)
# Out:
# Platform yang digunakan adalah linux
# Versi phyton 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]

# %% [markdown]
# Penugasan 04 - Modul Buatan Sendiri

# %%
# %%writefile konversi.py

def cel_to_fah(c):
    fahrenheit = (c * 9/5) + 32
    return fahrenheit

def fah_to_cel(f):
    celcius = (f - 32) * 5/9
    return celcius
# Out:
# Writing konversi.py

# %%
import konversi

suhu_c = int(input("Masukkan suhu dalam celcius = "))
suhu_f =konversi.cel_to_fah(suhu_c)
print(f"{suhu_c}°C = {suhu_f}°F")

suhu_f2 = int(input("Masukkan suhu dalam fahrenheit = "))
suhu_c2 = konversi.fah_to_cel(suhu_f2)
print(f"{suhu_f2}°F = {suhu_c2}°C")
# Out:
# Masukkan suhu dalam celcius = 50
# 50°C = 122.0°F
# Masukkan suhu dalam fahrenheit = 122
# 122°F = 50.0°C

# %% [markdown]
# Penugasan 05 - Instalasi Library Pihak Ketiga

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd

data_mahasiswa = {
    'NIM': ['2301001', '2301002', '2301003', '2301004', '2301005'],
    'Nama': ['Revo Setyo', 'Angga Kurnia', 'Pandu Wicaksono', 'Rhafi Hairy', 'Bimo Rajendra'],
    'Prodi': ['Informatika', 'Sistem Informasi', 'Informatika', 'Teknik Komputer', 'Sistem Informasi']
}

df_mahasiswa = pd.DataFrame(data_mahasiswa)

print("Data Mahasiswa:")
print(df_mahasiswa)
# Out:
# Data Mahasiswa:
#        NIM             Nama             Prodi
# 0  2301001       Revo Setyo       Informatika
# 1  2301002     Angga Kurnia  Sistem Informasi
# 2  2301003  Pandu Wicaksono       Informatika
# 3  2301004      Rhafi Hairy   Teknik Komputer
# 4  2301005    Bimo Rajendra  Sistem Informasi

# %% [markdown]
# Penugasan 06 - Studi Kasus Mini

# %%
# %%writefile laporan.py

def tampilkan_skor(benar, salah):
    """Menampilkan ringkasan skor"""
    total = benar + salah
    skor = (benar / total) * 100

    print("\n" + "="*40)
    print("HASIL SKOR KUIS :")
    print("="*40)
    print(f"Benar  : {benar}")
    print(f"Salah  : {salah}")
    print(f"Skor   : {skor:.0f}")
    print("="*40)
# Out:
# Overwriting laporan.py

# %%
import random
import laporan

jumlah_soal = 5

benar = 0
salah = 0

print("KUIS PENJUMLAHAN")
print("="*40)

for i in range(1, jumlah_soal + 1):
    angka1 = random.randint(1, 20)
    angka2 = random.randint(1, 20)
    jawaban_benar = angka1 + angka2

    print(f"\nSoal {i}: {angka1} + {angka2} = ?")
    jawaban = int(input("Jawaban: "))

    if jawaban == jawaban_benar:
        print("✓ Benar!")
        benar += 1
    else:
        print(f"✗ Salah! Jawaban: {jawaban_benar}")
        salah += 1

laporan.tampilkan_skor(benar, salah)
# Out:
# KUIS PENJUMLAHAN
# ========================================
#
# Soal 1: 18 + 13 = ?
# Jawaban: 31
# ✓ Benar!
#
# Soal 2: 12 + 8 = ?
# Jawaban: 20
# ✓ Benar!
#
# Soal 3: 7 + 13 = ?
# Jawaban: 19
# ✗ Salah! Jawaban: 20
#
# Soal 4: 18 + 4 = ?
# Jawaban: 22
# ✓ Benar!
#
# Soal 5: 18 + 20 = ?
# Jawaban: 38
# ✓ Benar!
#
# ========================================
# HASIL KUIS
# ========================================
# Benar  : 4
# Salah  : 1
# Skor   : 80
# ========================================
