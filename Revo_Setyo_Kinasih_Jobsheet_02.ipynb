# %% [markdown]
# <a href="https://colab.research.google.com/github/RevolZ13370/Revo-Setyo-Kinasih-ALPRO/blob/Jobsheet-01/Revo_Setyo_Kinasih_Jobsheet_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Praktikum 01. Pengenalan Variabel dan Tipe Data

# %%
# Integer
umur = 20
print("Umur:", umur, "→", type(umur))

# Float
tinggi = 170.5
print("Tinggi:", tinggi, "→", type(tinggi))

# String
nama = "Andi"
print("Nama:", nama, "→", type(nama))

# Boolean
is_mahasiswa = True
print("Status Mahasiswa:", is_mahasiswa, "→", type(is_mahasiswa))

# List
nilai = [80, 85, 90]
print("Nilai:", nilai, "→", type(nilai))

# Tuple
koordinat = (10, 20)
print("Koordinat:", koordinat, "→", type(koordinat))

# Dictionary
mahasiswa = {"nama": "Andi", "umur": 20, "prodi": "TRK"}
print("Data Mahasiswa:", mahasiswa, "→", type(mahasiswa))

# Set
hobi = {"membaca", "olahraga", "musik"}
print("Hobi:", hobi, "→", type(hobi))
# Out:
# Umur: 20 → <class 'int'>
# Tinggi: 170.5 → <class 'float'>
# Nama: Andi → <class 'str'>
# Status Mahasiswa: True → <class 'bool'>
# Nilai: [80, 85, 90] → <class 'list'>
# Koordinat: (10, 20) → <class 'tuple'>
# Data Mahasiswa: {'nama': 'Andi', 'umur': 20, 'prodi': 'TRK'} → <class 'dict'>
# Hobi: {'olahraga', 'membaca', 'musik'} → <class 'set'>

# %% [markdown]
# # Praktikum 02. Input dan Output Dasar

# %%
# Input string
nama = input("Masukkan nama Anda: ")

# Input integer
umur = int(input("Masukkan umur Anda: "))

# Input float
tinggi = float(input("Masukkan tinggi badan (cm): "))

# Output standar
print("Halo,", nama, "umur Anda:", umur, "tahun, tinggi:", tinggi, "cm")

# Output dengan format()
print("Halo {0}, umur Anda {1} tahun, tinggi {2} cm".format(nama, umur, tinggi))

# Output dengan f-string
print(f"Halo {nama}, umur Anda {umur} tahun, tinggi {tinggi} cm")
# Out:
# Masukkan nama Anda: Revo
# Masukkan umur Anda: 18
# Masukkan tinggi badan (cm): 177.0
# Halo, Revo umur Anda: 18 tahun, tinggi: 177.0 cm
# Halo Revo, umur Anda 18 tahun, tinggi 177.0 cm
# Halo Revo, umur Anda 18 tahun, tinggi 177.0 cm

# %% [markdown]
# # Praktikum 03. Operator Aritmatika

# %%
a = 20
b = 4

print("a + b =", a + b)
print("a - b =", a - b)
print("a * b =", a * b)
print("a / b =", a / b)
print("a // b =", a // b)
print("a % b =", a % b)
print("a ** b =", a ** b)
# Out:
# a + b = 24
# a - b = 16
# a * b = 80
# a / b = 5.0
# a // b = 5
# a % b = 0
# a ** b = 160000

# %% [markdown]
# # Praktikum 04. Operator Relasional

# %%
x = 10
y = 20

print("x == y :", x == y)
print("x != y :", x != y)
print("x < y :", x < y)
print("x > y :", x > y)
print("x <= y :", x <= y)
print("x >= y :", x >= y)
# Out:
# x == y : False
# x != y : True
# x < y : True
# x > y : False
# x <= y : True
# x >= y : False

# %% [markdown]
# # Praktikum 05. Operator Logika dengan Studi Kasus Nyata

# %%
# Operator logika dasar
a = True
b = False

print("a and b =", a and b)
print("a or b =", a or b)
print("not a =", not a)

# Studi kasus nyata: kelulusan
nilai = int(input("Masukkan nilai ujian: "))
hadir = int(input("Masukkan jumlah kehadiran: "))

lulus_nilai = nilai >= 60
lulus_hadir = hadir >= 12 # dari 16 pertemuan

if lulus_nilai and lulus_hadir:
  print("Status: LULUS")
else:
  print("Status: TIDAK LULUS")
# Out:
# a and b = False
# a or b = True
# not a = False
# Masukkan nilai ujian: 75
# Masukkan jumlah kehadiran: 14
# Status: LULUS

# %% [markdown]
# # Praktikum 06. Program Kasir Sederhana

# %%
barang = input("Masukkan nama barang: ")
harga = float(input("Masukkan harga barang: "))
jumlah = int(input("Masukkan jumlah barang: "))

total = harga * jumlah

# Aturan diskon
if total >= 100000:
  diskon = 0.2
elif total >= 50000:
  diskon = 0.1
else:
  diskon = 0

potongan = total * diskon
bayar = total - potongan

print("\n===== Struk Belanja =====")
print(f"Barang : {barang}")
print(f"Jumlah : {jumlah}")
print(f"Total : Rp {total}")
print(f"Diskon : {diskon * 100}%")
print(f"Bayar : Rp {bayar}")
# Out:
# Masukkan nama barang: Matcha Latte
# Masukkan harga barang: 23000
# Masukkan jumlah barang: 3
#
# ===== Struk Belanja =====
# Barang : Matcha Latte
# Jumlah : 3
# Total : Rp 69000.0
# Diskon : 10.0%
# Bayar : Rp 62100.0

# %% [markdown]
# # Penugasan 01. Identitas Mahasiswa

# %%
# Menyimpan data
nama = "Revo"
umur = 18
tinggi = 177.0
status = True

# Output menggunakan format f-string
print(f"Nama Anda {nama}, umur Anda {umur} tahun, tinggi {tinggi} cm, status aktif : {status}")
# Out:
# Nama Anda Revo, umur Anda 18 tahun, tinggi 177.0 cm, status aktif : True

# %% [markdown]
# # Penugasan 02. Operasi Aritmatika

# %%
# Input nilai a dna b
a = int(input("Masukkan nilai a: "))
b = int(input("Masukkan nilai b: "))

# Output hasil dari operasi aritmatika dari kedua nilai
print("a + b = ", a + b)
print("a - b = ", a - b)
print("a * b = ", a * b)
print("a / b = ", a / b)
print("a % b =", a % b)
print("a ** b = ", a ** b)
# Out:
# Masukkan nilai a: 12
# Masukkan nilai b: 4
# a + b =  16
# a - b =  8
# a * b =  48
# a / b =  3.0
# a % b = 0
# a ** b =  20736

# %% [markdown]
# # Penugasan 03. Konversi Nilai

# %%
# Input nilai yang akan dikonversikan
input_value = float(input("Masukkan angka : "))

# Output menampilkan nilai yang sudah dikonversi menjadi variabel lain
print(int(input_value))
print(str(input_value))
print(round(input_value))
# Out:
# Masukkan angka : 17.6
# 17
# 17.6
# 18

# %% [markdown]
# # Penugasan 04. Operator Relasional

# %%
# Input nilai a dan b
a = float(input("Masukkan nilai a: "))
b = float(input("Masukkan nilai b: "))

# Output menampilkan hasil operator operator relasional dari kedua nilai
print(f"{a} == {b} : {a == b}")
print(f"{a} != {b} : {a != b}")
print(f"{a} < {b}  : {a < b}")
print(f"{a} > {b}  : {a > b}")
print(f"{a} <= {b} : {a <= b}")
print(f"{a} >= {b} : {a >= b}")
# Out:
# Masukkan nilai a: 15
# Masukkan nilai b: 14
# 15.0 == 14.0 : False
# 15.0 != 14.0 : True
# 15.0 < 14.0  : False
# 15.0 > 14.0  : True
# 15.0 <= 14.0 : False
# 15.0 >= 14.0 : True
