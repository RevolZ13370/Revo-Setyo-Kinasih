# %% [markdown]
# <a href="https://colab.research.google.com/github/RevolZ13370/Revo-Setyo-Kinasih-ALPRO/blob/Jobsheet-01/Revo_Setyo_Kinasih_Jobsheet_07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Praktikum 01. Tuple: Data Tetap yang Tidak Bisa Diubah

# %%
koordinat = (7.05, 110.44)
print("Lintang:", koordinat[0])
print("Bujur:", koordinat[1])
# Out:
# Lintang: 7.05
# Bujur: 110.44

# %% [markdown]
# # Praktikum 02. Dictionary Dasar: Menyimpan Data Mahasiswa

# %%
mahasiswa= {
    "NIM"   : "20251001",
    "Nama"  : "Andi",
    "Prodi" : "TRK"
}

print("NIM    :", mahasiswa["NIM"])
print("Nama   :", mahasiswa["Nama"])
print("Prodi  :", mahasiswa["Prodi"])
# Out:
# NIM    : 20251001
# Nama   : Andi
# Prodi  : TRK

# %% [markdown]
# # Praktikum 03. Operasi pada Dictionary

# %%
mahasiswa = {
    "NIM": "20251001",
    "Nama": "Andi",
    "Prodi": "TRK"
}

mahasiswa["Umur"] = 20 # menambah data
mahasiswa["Prodi"] = "Teknik Komputer" # memperbarui data
del mahasiswa["Umur"] # menghapus data

print(mahasiswa)
# Out:
# {'NIM': '20251001', 'Nama': 'Andi', 'Prodi': 'Teknik Komputer'}

# %% [markdown]
# # Praktikum 04. Set dan Operasi Himpunan

# %%
A = {1, 2, 3, 4}
B = {3, 4, 5, 6}

print("Union:", A | B)
print("Intersection:", A & B)
print("Difference:", A - B)
# Out:
# Union: {1, 2, 3, 4, 5, 6}
# Intersection: {3, 4}
# Difference: {1, 2}

# %% [markdown]
# # Praktikum 05. Studi Kasus: Data Mahasiswa dan Mata Kuliah

# %%
mhs1 = {"Algoritma", "Matematika", "Bahasa Inggris"}
mhs2 = {"Algoritma", "Basis Data", "Matematika"}

print("Mata kuliah Mhs1:", mhs1)
print("Mata kuliah Mhs2:", mhs2)
print("Mata kuliah yang sama:", mhs1 & mhs2)
# Out:
# Mata kuliah Mhs1: {'Algoritma', 'Bahasa Inggris', 'Matematika'}
# Mata kuliah Mhs2: {'Algoritma', 'Matematika', 'Basis Data'}
# Mata kuliah yang sama: {'Algoritma', 'Matematika'}

# %% [markdown]
# # Praktikum 06. Studi Kasus Dictionary: Daftar Nilai Mahasiswa

# %%
nilai_mahasiswa = {
  "Andi": 80,
  "Budi": 75,
  "Cici": 90
}

for nama, nilai in nilai_mahasiswa.items():
  print(f"{nama}: {nilai}")

rata = sum(nilai_mahasiswa.values()) / len(nilai_mahasiswa)
print(f"Rata-rata nilai: {rata:.2f}")
# Out:
# Andi: 80
# Budi: 75
# Cici: 90
# Rata-rata nilai: 81.67

# %% [markdown]
# # Penugasan 01. Tuple Sederhana

# %%
mahasiswa = ("Budi", 20, "Teknik Komputer")

# Menampilkan masing-masing elemen dengan indexing
print("Nama   :", mahasiswa[0])
print("Umur   :", mahasiswa[1])
print("Prodi  :", mahasiswa[2])
# Out:
# Nama   : Budi
# Umur   : 20
# Prodi  : Teknik Komputer

# %% [markdown]
# # Penugasan 02. Tuple Tidak Bisa Diubah

# %%
tes_tuple = (1, 2, 3)
tes_tuple[1] = 0

print("Tuple setelah mencoba diubah : ", test_tuple)

# Error terjadi karena sifat tuple adalah Imutable atau tidak dapat diubah.
# Jadi, ketika kita mencoba untuk mengubah nilai yang berada di dalam tuple tersebut,
# Error akan muncul.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-551505827.py in <cell line: 0>()
#       1 tes_tuple = (1, 2, 3)
# ----> 2 tes_tuple[1] = 0
#       3
#       4 print("Tuple setelah mencoba diubah : ", test_tuple)
#       5
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# # Penugasan 03. Dictionary Dasar

# %%
tes_dictionary = {
    "Judul": "Algoritma",
    "Penulis": "Munir",
    "Tahun": 2021
}

print("Judul   : ", tes_dictionary["Judul"])
print("Penulis : ", tes_dictionary["Penulis"])
print("Tahun   : ", tes_dictionary["Tahun"])
# Out:
# Judul   :  Algoritma
# Penulis :  Munir
# Tahun   :  2021

# %% [markdown]
# # Penugasan 04. Operasi Dictionary

# %%
dosen = {"NIP": "12345", "Nama": "Budi", "Prodi": "TRK"}

dosen["Umur"] = 40
dosen["Prodi"] = "Teknik Komputer"
del dosen["Umur"]

print(dosen)
# Out:
# {'NIP': '12345', 'Nama': 'Budi', 'Prodi': 'Teknik Komputer'}

# %% [markdown]
# # Penugasan 05. Set dan Himpunan

# %%
A = {"Matematika", "Algoritma", "Bahasa Inggris"}
B = {"Algoritma", "Basis Data", "Matematika"}

print("Union        : ", A | B)
print("Intersection : ", A & B)
print("Difference   : ", A - B)
# Out:
# Union        :  {'Algoritma', 'Matematika', 'Basis Data', 'Bahasa Inggris'}
# Intersection :  {'Algoritma', 'Matematika'}
# Difference   :  {'Bahasa Inggris'}

# %% [markdown]
# # Penugasan 06. Studi Kasus Dictionary

# %%
data_nilai= {"Andi": 85, "Budi": 90, "Cici": 78}

for nama, nilai in data_nilai.items():
  rata = sum(data_nilai.values()) / len(data_nilai)
  print(f"Nilai {nama} : {nilai}")

print(f"Rata-rata nilai : {rata:.2f}")
# Out:
# Nilai Andi : 85
# Nilai Budi : 90
# Nilai Cici : 78
# Rata-rata nilai : 84.33

# %% [markdown]
# # Penugasan 07. Studi Kasus Set – Klub Mahasiswa

# %%
A = {"Andi", "Budi", "Cici"}
B = {"Cici", "Deni", "Eka"}

print("Daftar seluruh anggota: ", A | B)
print("Daftar anggota yang ada di kedua klub: ", A & B)
print("Anggota yang hanya ada di Klub A tetapi tidak di Klub B: ", A - B)
# Out:
# Daftar seluruh anggota:  {'Eka', 'Andi', 'Deni', 'Cici', 'Budi'}
# Daftar anggota yang ada di kedua klub:  {'Cici'}
# Anggota yang hanya ada di Klub A tetapi tidak di Klub B:  {'Andi', 'Budi'}
